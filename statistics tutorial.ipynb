# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("data.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.shape
# Out:
# (569, 33)

# %%
m = plt.hist(df[df["diagnosis"] == "M"].radius_mean)
b=plt.hist(df[df["diagnosis"] =="B"].radius_mean)
plt.legend()
plt.xlabel("Radius Mean Values")
plt.ylabel("Frequency")
plt.title("Histogram of Radius Mean for Bening and Malignant Tumors")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
desc=df.describe().transpose()
desc
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
plt.boxplot(df.radius_mean)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25d94a46978>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25d94a46da0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25d94a46550>],
#  'medians': [<matplotlib.lines.Line2D at 0x25d94a526d8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25d94a52a20>],
#  'means': []}

# %%
desc['iqr']=desc['75%']-desc['25%']
desc['uppwhisk']=desc['75%']+(1.5*(desc['iqr']))
desc['lowwhisk']=desc['25%']-(1.5*(desc['iqr']))

# %%
import thinkplot
import thinkstats2

# %%
df_be=df[df.diagnosis=="M"]
cdf=thinkstats2.Cdf(df_be.radius_mean)
thinkplot.Cdf(cdf)
# Out:
# {'xscale': 'linear', 'yscale': 'linear'}

# %%
print("Outliers: ",df_be[(df_be.radius_mean < desc['lowwhisk'].radius_mean) | (df_be.radius_mean > desc['lowwhisk'].radius_mean )].radius_mean.values)
# Out:
# Outliers:  [17.99 20.57 19.69 11.42 20.29 12.45 18.25 13.71 13.   12.46 16.02 15.78
#  19.17 15.85 13.73 14.54 14.68 16.13 19.81 15.34 21.16 16.65 17.14 14.58
#  18.61 15.3  17.57 18.63 11.84 17.02 19.27 16.13 16.74 14.25 14.99 13.48
#  13.44 10.95 19.07 13.28 13.17 18.65 13.17 18.22 15.1  19.21 14.71 14.25
#  12.68 14.78 18.94 17.2  13.8  16.07 18.05 20.18 25.22 19.1  18.46 14.48
#  19.02 15.37 15.06 20.26 14.42 13.61 13.11 22.27 14.87 15.78 17.95 18.66
#  24.25 13.61 19.   19.79 15.46 16.16 18.45 12.77 14.95 16.11 11.8  17.68
#  19.19 19.59 23.27 16.78 17.47 13.43 15.46 16.46 27.22 21.09 15.7  15.28
#  18.31 14.22 12.34 14.86 13.77 18.08 19.18 14.45 17.54 23.29 13.81 15.12
#  17.01 20.58 28.11 17.42 14.19 13.86 19.8  19.53 15.75 12.83 17.05 20.51
#  23.21 20.48 17.46 19.4  20.94 19.73 17.3  19.45 13.96 19.55 15.32 15.66
#  15.53 20.31 17.35 17.29 15.61 17.19 20.73 21.75 17.93 18.81 19.16 19.4
#  16.24 11.76 19.53 20.09 18.22 20.16 20.34 16.27 16.26 16.03 17.06 18.77
# ...

# %%
df.drop(df[(df['radius_mean']<desc.loc['radius_mean'].lowwhisk)|
        (df['radius_mean']>desc.loc['radius_mean'].uppwhisk)].index,inplace=True)

# %%
plt.boxplot(df.radius_mean)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25d95f34358>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25d95f349e8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25d95f29f28>],
#  'medians': [<matplotlib.lines.Line2D at 0x25d95f34e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25d95f3e400>],
#  'means': []}

# %%
df.radius_mean.describe()
# Out:
# count    532.000000
# mean      13.681427
# std        3.079175
# min        6.981000
# 25%       11.600000
# 50%       13.110000
# 75%       15.100000
# max       27.220000
# Name: radius_mean, dtype: float64

# %%
sns.jointplot(df_be.radius_mean,df_be.area_mean,kind='regg')

# %%
f,ax=plt.subplots(figsize = (18,18))
sns.heatmap(df_be.corr(method="pearson"),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)

# %%
np.cov(df["radius_mean"],df["area_mean"])
# Out:
# array([[8.83521757e+00, 8.03994069e+02],
#        [8.03994069e+02, 7.43455424e+04]])

# %%
df.radius_mean.cov(df.area_mean)
# Out:
# 803.9940685623963

# %%
from scipy.stats import ttest_1samp, ttest_ind, mannwhitneyu, levene, shapiro
t_statistic, p_value = ttest_ind(df.radius_mean,df["area_mean"])
print(t_statistic, p_value)
# Out:
# -49.40812466058215 7.593964720220938e-277
